# %%
import matplotlib.pyplot as plt

# Data
metrics = ['Accuracy', 'Loss']
before_fine_tuning = [60.0, 1.20]
after_fine_tuning = [85.0, 0.45]

x = range(len(metrics))  # the label locations

fig, ax = plt.subplots()
bar_width = 0.35
rects1 = ax.bar(x, before_fine_tuning, bar_width, label='Before Fine-Tuning')
rects2 = ax.bar([p + bar_width for p in x], after_fine_tuning, bar_width, label='After Fine-Tuning')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Metric')
ax.set_ylabel('Value')
ax.set_title('Performance Metrics Before and After Fine-Tuning')
ax.set_xticks([p + bar_width/2 for p in x])
ax.set_xticklabels(metrics)
ax.legend()

fig.tight_layout()

plt.show()

# %% [markdown]
# 3. Example Visualizations
# Table:
# +----------------+---------------------+-------------------+-------------+
# | Metric         | Before Fine-Tuning | After Fine-Tuning | Improvement |
# +----------------+---------------------+-------------------+-------------+
# | Accuracy       | 60.0%               | 85.0%             | +25.0%      |
# | Loss           | 1.20                | 0.45              | -0.75       |
# +----------------+---------------------+-------------------+-------------+
